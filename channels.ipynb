# %% [markdown]
# ## Import library

# %%
from googleapiclient.discovery import build

# %%
youTubeApiKey=your_youTubeApiKey
youtube=build('youtube','v3',developerKey=youTubeApiKey)
channelId='UCr2dD3s19bdcw4qjuUTQKiQ'

# %% [markdown]
# ## Statistics

# %%
statdata=youtube.channels().list(part='statistics',id=channelId).execute()
statdata
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/Dgf-XRvjCqWHDijYBQc0AmhjXKo"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/wROiNAQO-zv0x_AkVhpyo5rBoVE"',
#    'id': 'UCr2dD3s19bdcw4qjuUTQKiQ',
#    'statistics': {'viewCount': '3693',
#     'commentCount': '0',
#     'subscriberCount': '316',
#     'hiddenSubscriberCount': False,
#     'videoCount': '62'}}]}

# %%
stats=statdata['items'][0]['statistics']
stats
# Out:
# {'viewCount': '3693',
#  'commentCount': '0',
#  'subscriberCount': '316',
#  'hiddenSubscriberCount': False,
#  'videoCount': '62'}

# %%
videoCount=stats['videoCount']
videoCount
# Out:
# '62'

# %%
viewCount=stats['viewCount']
viewCount
# Out:
# '3693'

# %%
suscriberCount=stats['subscriberCount']
suscriberCount
# Out:
# '316'

# %% [markdown]
# ## Snippet

# %%
snippetdata=youtube.channels().list(part='snippet',id=channelId).execute()
snippetdata
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/pTyKj5O_jg_orH_A3UDCKyYEPpU"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/B27Tz_YPK1mkcXvNgzpCgjsWSjM"',
#    'id': 'UCr2dD3s19bdcw4qjuUTQKiQ',
#    'snippet': {'title': 'Rajni Sharma Maths Classes',
#     'description': 'Hello Viewers, Welcome to Rajni Sharma Maths Classes\n\nMy name is Rajni Sharma and this channel is for all the people searching for Online Maths classes. Although there are already much stuff available on the Internet but students do prefer content which explains everything in details right from the beginning.\n\nYou will be finding Maths lectures for the following:\n\n1. Class 10th Maths Video Lectures\n2. Class 11th Maths Solutions\n3. Class 12th Online Maths\n4. B.Sc. First Semester Maths\n5. B.Tech. Maths Lectures\n6. B. Com. Maths \nMany other degree courses Maths lectures.\n\nWe are uploading one video everyday and currently covering the full syllabus of Class 10 Maths. Soon we will be uploading further lectures of Other classes and degree courses.\n\nDo Subscribe the Channel and Press the bell icon to get notified of any new video uploads.\n\nStudents usually search for:\nClass 10 Maths Lectures\nClass 10 Maths Lectures in Hindi\nCBSE Class 10 Maths Lectures',
#     'customUrl': 'rajnisharmamathsclasses',
#     'publishedAt': '2019-06-26T02:36:45.000Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AGF-l79FPy9GCfPZItSmGJfb-NUUeYNyEo0tnoLETQ=s88-c-k-c0xffffffff-no-rj-mo',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/a/AGF-l79FPy9GCfPZItSmGJfb-NUUeYNyEo0tnoLETQ=s240-c-k-c0xffffffff-no-rj-mo',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/a/AGF-l79FPy9GCfPZItSmGJfb-NUUeYNyEo0tnoLETQ=s800-c-k-c0xffffffff-no-rj-mo',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Rajni Sharma Maths Classes',
#      'description': 'Hello Viewers, Welcome to Rajni Sharma Maths Classes\n\nMy name is Rajni Sharma and this channel is for all the people searching for Online Maths classes. Although there are already much stuff available on the Internet but students do prefer content which explains everything in details right from the beginning.\n\nYou will be finding Maths lectures for the following:\n\n1. Class 10th Maths Video Lectures\n2. Class 11th Maths Solutions\n3. Class 12th Online Maths\n4. B.Sc. First Semester Maths\n5. B.Tech. Maths Lectures\n6. B. Com. Maths \nMany other degree courses Maths lectures.\n\nWe are uploading one video everyday and currently covering the full syllabus of Class 10 Maths. Soon we will be uploading further lectures of Other classes and degree courses.\n\nDo Subscribe the Channel and Press the bell icon to get notified of any new video uploads.\n\nStudents usually search for:\nClass 10 Maths Lectures\nClass 10 Maths Lectures in Hindi\nCBSE Class 10 Maths Lectures'},
#     'country': 'IN'}}]}

# %%
title=snippetdata['items'][0]['snippet']['title']
title
# Out:
# 'Rajni Sharma Maths Classes'

# %%
description=snippetdata['items'][0]['snippet']['description']
description
# Out:
# 'Hello Viewers, Welcome to Rajni Sharma Maths Classes\n\nMy name is Rajni Sharma and this channel is for all the people searching for Online Maths classes. Although there are already much stuff available on the Internet but students do prefer content which explains everything in details right from the beginning.\n\nYou will be finding Maths lectures for the following:\n\n1. Class 10th Maths Video Lectures\n2. Class 11th Maths Solutions\n3. Class 12th Online Maths\n4. B.Sc. First Semester Maths\n5. B.Tech. Maths Lectures\n6. B. Com. Maths \nMany other degree courses Maths lectures.\n\nWe are uploading one video everyday and currently covering the full syllabus of Class 10 Maths. Soon we will be uploading further lectures of Other classes and degree courses.\n\nDo Subscribe the Channel and Press the bell icon to get notified of any new video uploads.\n\nStudents usually search for:\nClass 10 Maths Lectures\nClass 10 Maths Lectures in Hindi\nCBSE Class 10 Maths Lectures'

# %%
logo=snippetdata['items'][0]['snippet']['thumbnails']['default']['url']
logo
# Out:
# 'https://yt3.ggpht.com/a/AGF-l79FPy9GCfPZItSmGJfb-NUUeYNyEo0tnoLETQ=s88-c-k-c0xffffffff-no-rj-mo'

# %% [markdown]
# ## ContentDetails

# %%
contentdata=youtube.channels().list(id=channelId,part='contentDetails').execute()
playlist_id = contentdata['items'][0]['contentDetails']['relatedPlaylists']['uploads']
videos = []
next_page_token = None

while 1:
    res = youtube.playlistItems().list(playlistId=playlist_id, 
                                    part='snippet', 
                                    maxResults=50,
                                    pageToken=next_page_token).execute()
    videos += res['items']
    next_page_token = res.get('nextPageToken')

    if next_page_token is None:
        break

print(videos)
# Out:
# [{'kind': 'youtube#playlistItem', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/UboQPP04VY2PnDcGkGxspIw6ijA"', 'id': 'VVVyMmREM3MxOWJkY3c0cWp1VVRRS2lRLk00QnlTLWp6ZVdJ', 'snippet': {'publishedAt': '2019-09-01T05:51:52.000Z', 'channelId': 'UCr2dD3s19bdcw4qjuUTQKiQ', 'title': 'Class 10th Exercise 3.3 | Question 3 (v) | NCERT Maths', 'description': "In this video we have discussed step by step solution of Question 3(v) of Exercise 3.3.\n\nFor previous videos you can check our Channel's playlist and\nSubscribe our channel.\n\nClass 10th Maths Question 3(v) Exercise 3.3\nClass 10th Maths 2020\nClass 10th Chapter 3\nClass 10th Maths Full Course", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/M4ByS-jzeWI/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/M4ByS-jzeWI/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/M4ByS-jzeWI/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/M4ByS-jzeWI/sddefault.jpg', 'width': 640, 'height': 480}}, 'channelTitle': 'Rajni Sharma Maths Classes', 'playlistId': 'UUr2dD3s19bdcw4qjuUTQKiQ', 'position': 0, 'resourceId': {'kind': 'youtube#video', 'videoId': 'M4ByS-jzeWI'}}}, {'kind': 'youtube#playlistItem', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/VnI7YH8UT1vphEadwOTti1DS9qc"', 'id': 'VVVyMmREM3MxOWJkY3c0cWp1VVRRS2lRLm5udWpsM2JtXzdB', 'snippet': {'publishedAt': '2019-08-31T04:02:08.000Z', 'channelId': 'UCr2dD3s19bdcw4qjuUTQKiQ', 'title': 'Class 10th Exercise 3.3 | Question 3 (iv) | NCERT Maths', 'description': "In this video we have discussed step by step solution of Question 3(iv) of Exercise 3.3.\n\nFor previous videos you can check our Channel's playlist and subscribe our channel.\n\nClass 10th Maths Question 3 (iv) Exercise 3.3\nClass 10th Maths 2020\nClass 10th Chapter 3\nClass 10th Maths Full Course", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nnujl3bm_7A/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/nnujl3bm_7A/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/nnujl3bm_7A/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/nnujl3bm_7A/sddefault.jpg', 'width': 640, 'height': 480}}, 'channelTitle': 'Rajni Sharma Maths Classes', 'playlistId': 'UUr2dD3s19bdcw4qjuUTQKiQ', 'position': 1, 'resourceId': {'kind': 'youtube#video', 'videoId': 'nnujl3bm_7A'}}}, {'kind': 'youtube#playlistItem', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/AQ1WFa7Zc7lkcvF5g3i4TnrVBlM"', 'id': 'VVVyMmREM3MxOWJkY3c0cWp1VVRRS2lRLmY2Sm56R2dicVhv', 'snippet': {'publishedAt': '2019-08-30T04:10:14.000Z', 'channelId': 'UCr2dD3s19bdcw4qjuUTQKiQ', 'title': 'Class 10th Exercise 3.3 | Question 3 (iii) | NCERT Maths', 'description': "In this video we have discussed step by step solution of Question 3(iii) of Exercise 3.3.\n\nFor previous videos you can check our Channel's playlist and subscribe our channel.\n\nClass 10th Maths Question 3(iii) Exercise 3.3\nClass 10th Maths 2020\nClass 10th Chapter 3\nClass 10th Maths Full Course", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/f6JnzGgbqXo/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/f6JnzGgbqXo/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/f6JnzGgbqXo/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/f6JnzGgbqXo/sddefault.jpg', 'width': 640, 'height': 480}}, 'channelTitle': 'Rajni Sharma Maths Classes', 'playlistId': 'UUr2dD3s19bdcw4qjuUTQKiQ', 'position': 2, 'resourceId': {'kind': 'youtube#video', 'videoId': 'f6JnzGgbqXo'}}}, {'kind': 'youtube#playlistItem', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/wOKPDhDqHEtjWmjLdqJHRo8vILo"', 'id': 'VVVyMmREM3MxOWJkY3c0cWp1VVRRS2lRLmdsZ1RiQTktbTQ0', 'snippet': {'publishedAt': '2019-08-29T03:55:16.000Z', 'channelId': 'UCr2dD3s19bdcw4qjuUTQKiQ', 'title': 'Class 10th Exercise 3.3 | Question 3 (i), (ii) | N ...

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))
video_ids
# Out:
# ['M4ByS-jzeWI',
#  'nnujl3bm_7A',
#  'f6JnzGgbqXo',
#  'glgTbA9-m44',
#  'xwf7vroBL6E',
#  '0R9hJ4kobUc',
#  'VBCn2gWxSIQ',
#  'Keq4sXUqoMg',
#  'hRi15Gldy9U',
#  'gm17MR-uUAg',
#  'm4lPxz-z1es',
#  'FKAOERNJoiQ',
#  'ExAoD7FOInE',
#  '-EkkSVCBfcI',
#  'N5Nupje3aEA',
#  'FkVYjCYMBA4',
#  'GmqGTORdI70',
#  '1XGbb6rXMFU',
#  '_KOTJhDzmCc',
#  'R-MN99w6alc',
#  'BtM9FtzX0Vg',
#  'WEfrXa2rq6w',
#  '3OVLlhLHBOg',
#  'ZTdADgFmZSM',
#  'Dv1JYXxAB_s',
#  'T_YHztNDRrw',
#  'TBlvRQ3Q__U',
#  'KqoJ4vHjHDU',
#  '-9BTALCSf5w',
#  'k0LA1-UxGh4',
#  'TLYrqzB8E3g',
#  'ne63aHgWsvs',
#  'liWzozZHsPw',
#  'VKLx0jcFX8c',
#  '7YcbVltu6ks',
#  'X5rY5hdNvsw',
#  'XY2SYecZBeA',
#  'KNHIk0c6H7Y',
#  '-N_A4Qt0R10',
#  '9slDhZz9NqU',
#  'Rps7kD4lZO8',
#  'DKiHQpPBbs0',
#  'PpeVlgp-P_g',
#  'AfCWg7j5Uys',
#  'IMm2C2RcWO0',
#  'Qr8P-6C6w6A',
#  'mBP28yQiIRY',
#  '9H4EmINqCJA',
#  'gtRKVBfiv0k',
#  'T0kASi_pMEY',
#  'iZAmrhqCkF8',
#  'FkXUPkXWqdI',
#  'QZiOvnMMYqc',
#  'WjtnSK_GON8',
#  'YtBgpDgWy_o',
#  'eDQbYPGXp_M',
#  '4yyuWBq23XI',
#  'rJicOBeEyMc',
#  '_g2mCArU9os',
#  '5NgDLOhzyAg',
#  '53IF-ZdsChk']

# %%
stats = []
for i in range(0, len(video_ids), 40):
    res = (youtube).videos().list(id=','.join(video_ids[i:i+40]),part='statistics').execute()
    stats += res['items']

print(stats)
# Out:
# [{'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/vOvlIn1pOd8OkZkX0aRTDYOibv4"', 'id': 'M4ByS-jzeWI', 'statistics': {'viewCount': '13', 'likeCount': '7', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '1'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/l9jaUknalYx0OgeAv4Hs58c5Z1A"', 'id': 'nnujl3bm_7A', 'statistics': {'viewCount': '20', 'likeCount': '12', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '0'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/06Vdxjm-ZdFA5pJa51ArSIwigV0"', 'id': 'f6JnzGgbqXo', 'statistics': {'viewCount': '12', 'likeCount': '5', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '0'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/dRKCOIHFrT6YXn8daQ2yzYE31DM"', 'id': 'glgTbA9-m44', 'statistics': {'viewCount': '21', 'likeCount': '8', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '3'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/r-cKjHbY0Wi2P_a2O8Z9dbCD040"', 'id': 'xwf7vroBL6E', 'statistics': {'viewCount': '26', 'likeCount': '12', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '0'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/tnUT1lnAhQdxPLyo6CesjQyVSi4"', 'id': '0R9hJ4kobUc', 'statistics': {'viewCount': '22', 'likeCount': '12', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '2'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/1oFzwkaOjPz3M8zSgaIK63rRhdQ"', 'id': 'VBCn2gWxSIQ', 'statistics': {'viewCount': '24', 'likeCount': '14', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '4'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/9M-XjSA6WOmn2yJ9THt2SnwRIcU"', 'id': 'Keq4sXUqoMg', 'statistics': {'viewCount': '23', 'likeCount': '11', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '0'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/-iZdZ1cYP5M-YLQgAns_jDWUkRY"', 'id': 'hRi15Gldy9U', 'statistics': {'viewCount': '27', 'likeCount': '12', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '0'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/jDw_TWJijiASa0KESRCBa1ZWRg0"', 'id': 'gm17MR-uUAg', 'statistics': {'viewCount': '15', 'likeCount': '10', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '1'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/IhNpIp-vQHilmljEJFahtAGnisU"', 'id': 'm4lPxz-z1es', 'statistics': {'viewCount': '18', 'likeCount': '11', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '0'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/ploOWDwmJY5IOf4WsEr9tlzxiS4"', 'id': 'FKAOERNJoiQ', 'statistics': {'viewCount': '18', 'likeCount': '11', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '0'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/m0DXECa8OloYCUiqQ8rKY3kX_fs"', 'id': 'ExAoD7FOInE', 'statistics': {'viewCount': '24', 'likeCount': '12', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '0'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/tsaNL02h_z_TdN-limaKgbuAS98"', 'id': '-EkkSVCBfcI', 'statistics': {'viewCount': '49', 'likeCount': '15', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '4'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/GCjE4fzAW6VvrWKAl8Mozs61rRs"', 'id': 'N5Nupje3aEA', 'statistics': {'viewCount': '24', 'likeCount': '12', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '1'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/NPtEa_HKKqYFgy7zNfKmFiBRfBM"', 'id': 'FkVYjCYMBA4', 'statistics': {'viewCount': '24', 'likeCount': '11', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '0'}}, {'kind': 'youtube#video', 'etag': '"8jEFfXBrqiSrcF6Ee7MQuz8XuAM/HAuWeDlaTl-np0Deo2OB44QrvFg"', 'id': 'GmqGTORdI70', 'statistics': {'viewCount': '29', 'likeCount': '9', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '0'}}, {'kind': ...

# %%
title=[]
liked=[]
disliked=[]
views=[]
url=[]
comment=[]
for i in range(len(videos)):      
        title.append((videos[i])['snippet']['title'])
        url.append("https://www.youtube.com/watch?v="+(all_videos[i])['snippet']['resourceId']['videoId'])
        liked.append(int((stats[i])['statistics']['likeCount']))
        disliked.append(int((stats[i])['statistics']['dislikeCount']))
        views.append(int((stats[i])['statistics']['viewCount']))
        comment.append(int((stats[i])['statistics']['commentCount']))

# %% [markdown]
# ## Result in DataFrame format

# %%
import pandas as pd
data={'title':title,'url':url,'liked':liked,'disliked':disliked,'views':views,'comment':comment}
df=pd.DataFrame(data)
df
# Out:
#                                                 title url  liked  disliked  \
# 0   Class 10th Exercise 3.3 | Question 3 (v) | NCE...          7         0
# 1   Class 10th Exercise 3.3 | Question 3 (iv) | NC...         12         0
# 2   Class 10th Exercise 3.3 | Question 3 (iii) | N...          5         0
# 3   Class 10th Exercise 3.3 | Question 3 (i), (ii)...          8         0
# 4   Class 10th Exercise 3.3 | Question 2 | NCERT M...         12         0
# 5   Class 10th Exercise 3.3 | Question 1 (v), (vi)...         12         0
# 6   Class 10th Exercise 3.3 | Question 1 (iii), (i...         14         0
# 7   Class 10th Exercise 3.3 | Question 1 (i), (ii)...         11         0
# 8   Algebraic Methods Of Solving a Pair of Linear ...         12         0
# 9   Class 10th Exercise 3.2 | Question 7 | NCERT M...         10         0
# 10  Class 10th Exercise 3.2 | Question 6 | NCERT M...         11         0
# 11  Class 10th Exercise 3.2 | Question 5 | NCERT M...         11         0
# 12  Class 10th Exercise 3.2 | Question 4 | NCERT M...         12         0
# 13  Class 10th Exercise 3.2 | Question 3 | NCERT M...         15         0
# 14  Class 10th Exercise 3.2 | Question 2 | NCERT M...         12         0
# 15  Class 10th Exercise 3.2 | Question 1 | NCERT M...         11         0
# 16  Class 10th Exercise 3.1 | Question 3 | NCERT M...          9         0
# 17  Class 10 Board Exam 2020 CBSE News | Two Separ...         11         1
# 18  Class 10th Exercise 3.1 | Question 2 | NCERT M...         10         0
# 19  Class 10th Exercise 3.1 | Question 1 |  NCERT ...         14         0
# 20  Pair Of Linear Equations in Two Variables - Gr...         11         0
# 21  Class 10th Exercise 2.3 | Question 5 | Polynom...         20         0
# 22  Class 10th Exercise 2.3 | Question 4 | Polynom...         15         0
# 23  Class 10th Exercise 2.3 | Question 3 | Polynom...         11         0
# 24  Class 10th Exercise 2.3 | Question 2 | Polynom...         11         1
# 25  Class 10th Exercise 2.3 | Question 1 | Polynom...         15         0
# 26  Division Algorithm for Polynomials Class 10 | ...         16         1
# 27  Class 10th Exercise 2.2 | Question 2 Part (iv)...         17         0
# 28  Class 10th Exercise 2.2 | Question 2 Part (i),...         15         0
# 29  Class 10th Exercise 2.2 | Question 1 Part (v) ...         13         0
# ..                                                ...  ..    ...       ...
# 31  Class 10th Exercise 2.2 Question 1 Part (i) & ...         17         0
# 32  Relationship B/W Zeros & Coefficients | Polyno...         16         0
# 33  Class 10th Question 1 | Exercise 2.1 Polynomia...         17         0
# 34  Graphical Representation of Zeroes | Polynomia...         19         1
# 35  Class 10th Chapter 2| Introduction to Polynomi...         17         0
# 36  Class 10th Exercise 1.4 | Question 3 Real Numb...         17         0
# 37  Class 10th Question 2 | Exercise 1.4 Real Numb...         17         0
# 38  Class 10th Question No 1 | Exercise 1.4 |  Rea...         14         0
# 39  Class 10th Maths Chapter 1 | Theorem 1.5, 1.6,...         21         0
# 40  Class 10th Exercise 1.3 | Question No. 3 | Rea...         24         1
# 41  Class 10th Exercise 1.3 | Question No. 2 | Rea...         21         0
# 42  Class 10th Exercise 1.3 |  Question 1 |  Real ...         18         0
# 43  Class 10th Chapter 1 | Theorm 1.4 Real Numbers...         20         0
# 44  Class 10th Chapter 1 | Theorem 1.3 | Real Numb...         15         0
# 45  Class 10th Exercise 1.2 | Question 7 Real Numb...         13         0
# 46  Class 10th Exercise 1.2 | Question No. 6 | Rea...         21         0
# 47  Class 10th Exercise 1.2 | Question No. 5 | Rea...         19         0
# 48  Class 10th Exercise 1.2 | Question No. 4 | Rea...         21         1
# 49  Class 10th Exercise 1.2 Question 3 | Real Numb...         15         2
# 50  Class 10th Exercise 1.2 | Question 2 Real Numb...         17         0
# 51  Class 10th Exercise 1.2 | Question 1 Real Numb...         20         0
# 52  HCF and LCM Class 10 | Chapter 1 Exercise 1.2 ...         21         1
# 53  Fundamental Theorem of Arithmetic Class 10 | R...         20         1
# 54  Class 10th Maths | Exercise 1.1 | Question 5 |...         21         0
# 55  Class 10th Exercise 1.1 | Question 4 | Real Nu...         31         0
# 56  Class 10th Exercise 1.1 | Question 3 | Real Nu...         18         0
# 57  Class 10th Exercise 1.1 | Question 2 | Real Nu...         12         0
# 58  Class 10th | Exercise 1. 1 | Question 1 | Real...         22         1
# 59  Euclid's Division Lemma Class 10 | Maths Chapt...         32         0
# 60  Real Numbers Chapter 1 Ex 1.1 Intro NCERT Clas...         41         2
#
#     views  comment
# 0      13        1
# 1      20        0
# 2      12        0
# 3      21        3
# 4      26        0
# 5      22        2
# 6      24        4
# 7      23        0
# 8      27        0
# 9      15        1
# 10     18        0
# 11     18        0
# 12     24        0
# 13     49        4
# 14     24        1
# 15     24        0
# 16     29        0
# 17     39        1
# 18     27        0
# 19     37        5
# 20     39        1
# 21     35        0
# 22     27        2
# 23     31        0
# 24     26        0
# 25     34        1
# 26     40        1
# 27     30        3
# 28     66        5
# 29     32        2
# ..    ...      ...
# 31     38        2
# 32     36        1
# 33    364        7
# 34    278        5
# 35     48        3
# 36     42        4
# 37     44        0
# 38     58        3
# 39     72        2
# 40     91        4
# 41     56        2
# 42     69        4
# 43     76        0
# 44     33        0
# 45     37        0
# 46     79        0
# 47     51        3
# 48    104        2
# 49     45        2
# 50     57        1
# 51     64        7
# 52     65        9
# 53    146        5
# 54     81        9
# 55    103        3
# 56     84        4
# 57     57        0
# 58     75        1
# 59    149        4
# 60    273        8
#
# [61 rows x 6 columns]
